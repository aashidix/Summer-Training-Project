# %%
#Decision Tree Regressor

# %%
'''
pandas, sklearn dec, ttsplit, sklearn-tree matplotlib, seaborn
load data, duplicated null, define x an dy
same devide trian and test data
dt= decidiontree regressor()
df.fit(x_train, y-train)
ypred=dt.predict
score
plt.figsize(24,10
            t

            
random forest reg with classifier
x, y with iloc, 
randomforest import with rf nsestiator, 
y predpred(xtest)
'''

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
df=pd.read_csv("salary_data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[["YearsExperience"]]
y=df[["Salary"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(x , y, test_size = 0.25 , random_state = 42)

# %%
dt= DecisionTreeRegressor()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(X_test)

# %%
dt.score(X_train, y_train)
# Out:
# 0.9999532463874449

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(24,10))


tree.plot_tree(dt, filled=True, feature_names=x.columns)

plt.show()

# %%
import pickle
with open("DT_Regressor_pickle.pkl", "wb") as file:
    pickle.dump(dt, file)

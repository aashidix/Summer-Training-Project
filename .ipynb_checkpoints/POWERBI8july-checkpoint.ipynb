# %%
''' uploading and saving the data
uploading: csv, excel, html, json, sql
saving: csv, excel, json, sql
saving a self made data in laptop: df.to_csv

'''
# Out:
# ' uploading and saving the data\nuploading: csv, excel, html, json, sql\nsaving: csv, excel, json, sql\nsaving a self made data in laptop: df.to_csv\n\n'

# %%
'''POWER BI
dashboard: 
clustered bar chart
waterfall
gauge
area
pie
donut
card: only numeric data
slicer: 
scatter plot/chart: 
input slicer:
DAX: new feature made from the pre=existing features. 2 types: implicit(only used one time) explicit (can be used multiple times)
click on NEW MEASURE then: name_of_newcol= sum ('sample-superstore'[Category]) then click on commit symbol:phone type
near the name of the sample: a table type symbol
for tranforming data: click on Transform data, power query editor will open, 
check the data manually first then clean, 
click button on column name ( use it to sort data accordingly: ascending, remove empty etc
using text filter we can filter data and ssee the data. 
make a dashboard at home. if heading is not taking, click on "use first row as header". 
or fill/ replace values using: Replace value option. 
can manage the features using manage parameters
merge queries using the merge query option
find duplicates, find null values, then to end it directly close the window
on the left hand side: three views: report table model dax tmdl
data modelling: used to merge and use data from one/more tables. methods:
1.startflake: {orders, customer, return delivery}find table which has common info from all the tables, one by one join all the tables to the
selected table, (in order tabel there will be a custid, same as customer table. click bboth features and the tables are joined and all the 
others are joined in the same way)
2.snakeflake: in orders most features are common to customer, so we join order to customer[data sharing is happening]. then we check in 
customer which tables have most common features to ither table. and so on. property: 
'''

# %%
#PROJECTS TO DO:
'''
1. Proj1 normal numpy
2. numpy quad

3. multiple slicer dashboard
4.single slicer dashboard


matplotlib: 
5.smiley
6.hut 

7.pandas:
take data clean with pandas
visualize using matplotlib
EXCEL

'''

# %%
# MAKE A SMILEY
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import matplotlib.patches as patches
from matplotlib.patches import Ellipse

#x1=[2,2,8,8,2]
#y1=[2,8,8,2,2]
#plt.plot(x1, y1)

a=Circle([3.5,9], .5, fill=True, color='pink')
plt.axis('equal')
plt.gca(). add_patch(a)

b=Circle([3.3,9.2], .05, fill=True, color='black')
plt.axis('equal')
plt.gca(). add_patch(b)

c=Circle([3.7,9.2], .05, fill=True, color='black')
plt.axis('equal')
plt.gca(). add_patch(c)

d=Circle([3.3,9.2], .007, fill=True, color='white')
plt.axis('equal')
plt.gca(). add_patch(d)

e=Circle([3.7,9.2], .007, fill=True, color='white')
plt.axis('equal')
plt.gca(). add_patch(e)



smile = patches.Arc((3.5, 8.87), 0.4, 0.25, angle=0, theta1=200, theta2=340)
plt.gca().add_patch(smile)

#smile= Arc([3.5, 8.87], 0.4, 0.25, angle=0, theta= 200)
#plt.axis('equal')
#plt.gca(). add_patch(smile)

plt.plot()
plt.show()

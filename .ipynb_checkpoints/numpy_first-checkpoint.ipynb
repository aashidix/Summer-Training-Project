# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img= Image.open(r"/Users/Aashi_Dixit/Desktop/SUMMER TRAINING/lily.jpg") #save img in same folder as the file we're working on; can also give path but it can lead to errors
img=np.array(img)
img[:,:,0]=np.clip(img[:,:,0]+90,0,225) # clip: overrides new parameter to the earlier parametre
plt.imshow(img) # shows earlier image
plt.axis("off") # no need for X and Y axis
plt.show() # shows new img with color grading

# %%
'''
LINEAR REGRESSION
MACHINE LEARNIN MODEL STEPS:
1. import all libraries that are useful (for ex. numpy, pandas, matplotlib, scikit-learn, tensorflow, keras, etc)
2. data import using pandas (pd.read_csv, pd.read_excel)
3.EDA/ preprocessing (data cleaning(check null, drop, fill), encoding, transforming, scaling)
* YOU NEED TO MAKE TARGET VARIBALE (X input variable,Y output variable)
4. data divide into 2 parts: training , testing (train_test_split(sklearn), 80,20)
5. model import (whichever we are using) lr=linearregression
6. Training data fitted into the model (lr.fit())
7. Make prediction using 'model_name_variable'.predict() (lr.predict)
8. Check the evaluation matrices (r2score, accuracy, f1 score) (accuracy should be more than 80%)
9. Convert model into pickle file
10. Making the GUI
11. pkl file adjust into  GUI code. 


'''

# %%
'''
import matplotlib as plt
seaborn
pickle

read_csv, head, isnull.sum, dropna(inplace=true), isnull.sum, shape, x=df[['colname']], y= df
from sklear.model_selection import ttsplit
X_train, X_test, y_train, y_test = ttsplit(x, y, test_size=0.2, (20% training, 80%training), random_state= 42(so that the data remains fixed))
from sklearn. import LR
lr=LR()
lr.fit(X_train, Y-train)
y_pred_lr.predict9X_test)
y pred
x-test
y_tes
from sklearn import r2score
r2=r2score(y-test, y-pred)
r2
'''

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import pickle as pkl

# %%
df=pd.read_csv("employee_salary_dataset.csv")

# %%
df.head()
# Out:
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091
# 4  Female      Delhi          132450

# %%
df.isnull().sum()
# Out:
# EmployeeID          0
# Name                0
# Department          0
# Experience_Years    0
# Education_Level     0
# Age                 0
# Gender              0
# City                0
# Monthly_Salary      0
# dtype: int64

# %%
df.shape
# Out:
# (50, 9)

# %%
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
x=df[['Experience_Years']]
y=df[['Monthly_Salary']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split (x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([[83605.51275839],
#        [86908.73597569],
#        [88560.34758434],
#        [81953.90114974],
#        [86908.73597569],
#        [83054.97555551],
#        [84706.58716416],
#        [88009.81038146],
#        [85257.12436704],
#        [85807.66156993]])

# %%
y_pred
# Out:
#     Experience_Years
# 13                 6
# 39                12
# 30                15
# 45                 3
# 17                12
# 48                 5
# 26                 8
# 25                14
# 32                 9
# 19                10

# %%
y_test
# Out:
#     Monthly_Salary
# 13           28436
# 39           68484
# 30           70714
# 45           88208
# 17           44738
# 48           28420
# 26          119660
# 25           30600
# 32          127946
# 19           74377

# %%
from sklearn.metrics import r2_score

# %%
r2= r2_score (y_test, y_pred)

# %%
r2
# Out:
# -0.2700756400465425

# %%
with open("LR_pickle.pkl", "wb") as file:
    pkl.dump(lr, file)

# %%
import streamlit as st

# %%
model = pkl.load(open("LR_pickle.pkl","rb"))

# %%
st.title('Student Dashboard')
area = st.number_input("Area")
bedrooms = st.number_input("Bedrooms")
age = st.number_input("Age")

if st.button("Predict"):
    result = model.predict([[area,bedrooms,age]])
    st.success(f"Price: {result[0]}")
# Out:
# 2026-07-13 21:36:34.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 21:36:34.541 Session state does not function when running a script without `streamlit run`
# 2026-07-13 21:36:34.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
